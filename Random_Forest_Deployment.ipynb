# %%
import pickle

# %%
loaded_model=pickle.load(open("Final_Random_ForestRegression.sav",'rb'))
rd_input=float(input("Enter R&D:"))
admin_input=float(input("Enter Admin:"))
mark_input=float(input("Enter Marketing:"))
fol_input=int(input("Enter 1 if state is florida else 0:"))
new_input=int(input("Enter 1 if state is newyork else 0:"))

result=loaded_model.predict([[rd_input,admin_input,mark_input,fol_input,new_input]])
# Out:
# Enter R&D: 165349.2
# Enter Admin: 136897.8
# Enter Marketing: 471784.1
# Enter 1 if state is florida else 0: 0
# Enter 1 if state is newyork else 0: 1
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([186600.32])
